# %% [markdown]
# <a href="https://colab.research.google.com/github/ZackAkil/optimising-basketball/blob/master/shot%20prediction/video_shrinking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Authenticate to GCS
from google.colab import auth
auth.authenticate_user()

# %%
# !gsutil cp gs://rugby-videos/VID_20181215_095232.mp4 .
# Out:
# Copying gs://rugby-videos/VID_20181215_095232.mp4...
# | [1 files][639.5 MiB/639.5 MiB]
# Operation completed over 1 objects/639.5 MiB.

# %%
# !ffmpeg -i VID_20181215_095232.mp4 -vf scale=160:-1 output_160.mp4
# Out:
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'VID_20181215_095232.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-12-15T09:52:32.000000Z
#     location        : +51.4807-000.1020/
#     location-eng    : +51.4807-000.1020/
#     com.android.version: 9
#   Duration: 00:07:23.30, start: 0.000000, bitrate: 12101 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 95 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-15T09:52:32.000000Z
#       handler_name    : SoundHandle
#     Stream #0:1(eng): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc, smpte170m), 1280x720, 12002 kb/s, SAR 1:1 DAR 16:9, 30.03 fps, 30 tbr, 90k tbn, 180k tbc (default)
#     Metadata:
#       creation_time   : 2018-12-15T09:52:32.000000Z
#       handler_name    : VideoHandle
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x56419560e000] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x5641947fe800] using SAR=1/1
# [libx264 @ 0x5641947fe800] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5641947fe800] profile High, level 1.1
# [libx264 @ 0x5641947fe800] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output_160.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     com.android.version: 9
#     location        : +51.4807-000.1020/
#     location-eng    : +51.4807-000.1020/
#     encoder         : Lavf57.83.100
#     Stream #0:0(eng): Video: h264 (libx264) (avc1 / 0x31637661), yuvj420p(pc), 160x90 [SAR 1:1 DAR 16:9], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2018-12-15T09:52:32.000000Z
#       handler_name    : VideoHandle
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       creation_time   : 2018-12-15T09:52:32.000000Z
#       handler_name    : SoundHandle
#       encoder         : Lavc57.107.100 aac
# Past duration 0.601662 too large
# Past duration 0.605324 too large
# Past duration 0.603996 too large
# Past duration 0.602654 too large
# Past duration 0.604332 too large
# Past duration 0.605995 too large
# Past duration 0.607658 too large
# Past duration 0.609322 too large
# Past duration 0.610985 too large
# Past duration 0.609322 too large
# Past duration 0.607658 too large
# Past duration 0.610664 too large
# Past duration 0.613655 too large
# Past duration 0.611992 too large
# Past duration 0.610329 too large
# Past duration 0.613655 too large
# Past duration 0.616997 too large
# Past duration 0.615654 too large
# Past duration 0.614326 too large
# Past duration 0.617332 too large
# Past duration 0.620323 too large
# Past duration 0.618660 too large
# Past duration 0.616997 too large
# Past duration 0.619987 too large
# Past duration 0.622993 too large
# Past duration 0.622322 too large
# Past duration 0.621666 too large
# Past duration 0.620995 too large
# Past duration 0.624992 too large
# Past duration 0.625328 too large
# Past duration 0.625664 too large
# Past duration 0.625999 too large
# Past duration 0.626320 too large
# Past duration 0.626656 too large
# Past duration 0.626991 too large
# Past duration 0.630333 too large
# Past duration 0.633659 too large
# Past duration 0.631660 too large
# Past duration 0.629662 too large
# Past duration 0.632988 too large
# Past duration 0.636330 too large
# Past duration 0.635323 too large
# Past duration 0.634331 too large
# Past duration 0.636665 too large
# Past duration 0.639000 too large
# Past duration 0.641319 too large
# Past duration 0.638329 too large
# Past duration 0.639656 too large
# Past duration 0.640999 too large
# Past duration 0.642326 too large
# Past duration 0.643654 too large
# Past duration 0.644997 too large
# Past duration 0.646324 too large
# Past duration 0.647652 too large
# Past duration 0.648994 too large
# Past duration 0.646660 too large
# Past duration 0.647987 too large
# Past duration 0.649330 too large
# Past duration 0.650658 too large
# Past duration 0.651985 too large
# Past duration 0.653328 too large
# Past duration 0.654655 too large
# Past duration 0.655998 too large
# Past duration 0.653999 too large
# Past duration 0.655327 too large
# Past duration 0.656654 too large
# Past duration 0.657997 too large
# Past duration 0.659325 too large
# Past duration 0.660652 too large
# Past duration 0.661995 too large
# Past duration 0.663322 too large
# Past duration 0.661324 too large
# Past duration 0.659325 too large
# Past duration 0.661995 too large
# Past duration 0.664665 too large
# Past duration 0.667320 too large
# Past duration 0.665321 too large
# Past duration 0.663322 too large
# Past duration 0.666664 too large
# Past duration 0.669991 too large
# Past duration 0.668327 too large
# Past duration 0.666664 too large
# Past duration 0.669655 too large
# Past duration 0.672661 too large
# Past duration 0.671989 too large
# Past duration 0.671333 too large
# Past duration 0.670662 too large
# Past duration 0.674660 too large
# Past duration 0.678658 too large
# Past duration 0.674995 too large
# Past duration 0.675987 too large
# Past duration 0.676994 too large
# Past duration 0.677986 too large
# Past duration 0.678993 too large
# Past duration 0.679985 too large
# Past duration 0.680992 too large
# Past duration 0.681999 too large
# Past duration 0.682991 too large
# Past duration 0.683998 too large
# Past duration 0.684990 too large
# Past duration 0.685997 too large
# Past duration 0.686989 too large
# Past duration 0.687996 too large
# Past duration 0.688988 too large
# Past duration 0.689995 too large
# Past duration 0.690987 too large
# Past duration 0.691994 too large
# Past duration 0.692986 too large
# Past duration 0.693993 too large
# Past duration 0.695000 too large
# Past duration 0.695992 too large
# Past duration 0.696999 too large
# Past duration 0.697990 too large
# Past duration 0.698997 too large
# Past duration 0.699989 too large
# Past duration 0.697319 too large
# Past duration 0.694664 too large
# Past duration 0.698662 too large
# Past duration 0.702660 too large
# Past duration 0.700996 too large
# Past duration 0.699333 too large
# Past duration 0.702324 too large
# Past duration 0.705330 too large
# Past duration 0.703651 too large
# Past duration 0.704994 too large
# Past duration 0.706322 too large
# Past duration 0.707664 too large
# Past duration 0.708992 too large
# Past duration 0.710320 too large
# Past duration 0.711662 too large
# Past duration 0.712990 too large
# Past duration 0.714333 too large
# Past duration 0.710991 too large
# Past duration 0.711998 too large
# Past duration 0.712990 too large
# Past duration 0.713997 too large
# Past duration 0.714989 too large
# Past duration 0.715996 too large
# Past duration 0.716988 too large
# Past duration 0.717995 too large
# Past duration 0.718987 too large
# Past duration 0.719994 too large
# Past duration 0.720985 too large
# Past duration 0.721992 too large
# Past duration 0.723000 too large
# Past duration 0.723991 too large
# Past duration 0.724998 too large
# Past duration 0.725990 too large
# Past duration 0.726997 too large
# Past duration 0.727989 too large
# Past duration 0.728996 too large
# Past duration 0.729988 too large
# Past duration 0.727654 too large
# Past duration 0.728996 too large
# Past duration 0.730324 too large
# Past duration 0.731667 too large
# Past duration 0.732994 too large
# Past duration 0.734322 too large
# Past duration 0.735664 too large
# Past duration 0.736992 too large
# Past duration 0.734322 too large
# Past duration 0.735329 too large
# Past duration 0.736320 too large
# Past duration 0.737328 too large
# Past duration 0.738319 too large
# Past duration 0.739326 too large
# Past duration 0.740318 too large
# Past duration 0.741325 too large
# Past duration 0.742332 too large
# Past duration 0.743324 too large
# Past duration 0.744331 too large
# Past duration 0.745323 too large
# Past duration 0.746330 too large
# Past duration 0.747322 too large
# Past duration 0.748329 too large
# Past duration 0.749321 too large
# Past duration 0.750328 too large
# Past duration 0.751320 too large
# Past duration 0.752327 too large
# Past duration 0.753319 too large
# Past duration 0.754326 too large
# Past duration 0.755333 too large
# Past duration 0.756325 too large
# Past duration 0.753990 too large
# Past duration 0.751656 too large
# Past duration 0.755653 too large
# Past duration 0.759666 too large
# Past duration 0.756996 too large
# Past duration 0.757988 too large
# Past duration 0.758995 too large
# Past duration 0.759987 too large
# Past duration 0.760994 too large
# Past duration 0.761986 too large
# Past duration 0.762993 too large
# Past duration 0.764000 too large
# Past duration 0.764992 too large
# Past duration 0.765999 too large
# Past duration 0.766991 too large
# Past duration 0.767998 too large
# Past duration 0.768990 too large
# Past duration 0.769997 too large
# Past duration 0.770988 too large
# Past duration 0.771996 too large
# Past duration 0.772987 too large
# Past duration 0.773994 too large
# Past duration 0.774986 too large
# Past duration 0.775993 too large
# Past duration 0.776985 too large
# Past duration 0.777992 too large
# Past duration 0.778999 too large
# Past duration 0.779991 too large
# Past duration 0.777657 too large
# Past duration 0.778664 too large
# Past duration 0.779655 too large
# Past duration 0.780663 too large
# Past duration 0.781654 too large
# Past duration 0.782661 too large
# Past duration 0.783653 too large
# Past duration 0.784660 too large
# Past duration 0.785652 too large
# Past duration 0.786659 too large
# Past duration 0.787666 too large
# Past duration 0.788658 too large
# Past duration 0.789665 too large
# Past duration 0.790657 too large
# Past duration 0.791664 too large
# Past duration 0.792656 too large
# Past duration 0.793663 too large
# Past duration 0.794655 too large
# Past duration 0.795662 too large
# Past duration 0.796654 too large
# Past duration 0.797661 too large
# Past duration 0.798653 too large
# Past duration 0.799660 too large
# Past duration 0.800652 too large
# Past duration 0.797661 too large
# Past duration 0.798988 too large
# Past duration 0.800331 too large
# Past duration 0.801659 too large
# Past duration 0.802986 too large
# Past duration 0.804329 too large
# Past duration 0.805656 too large
# Past duration 0.806999 too large
# Past duration 0.808327 too large
# Past duration 0.805656 too large
# Past duration 0.806999 too large
# Past duration 0.808327 too large
# Past duration 0.809654 too large
# Past duration 0.810997 too large
# Past duration 0.812325 too large
# Past duration 0.813652 too large
# Past duration 0.814995 too large
# Past duration 0.812325 too large
# Past duration 0.813652 too large
# Past duration 0.814995 too large
# Past duration 0.816322 too large
# Past duration 0.817665 too large
# Past duration 0.818993 too large
# Past duration 0.820320 too large
# Past duration 0.821663 too large
# Past duration 0.819664 too large
# Past duration 0.817665 too large
# Past duration 0.820320 too large
# Past duration 0.822990 too large
# Past duration 0.825661 too large
# Past duration 0.823662 too large
# Past duration 0.821663 too large
# Past duration 0.825325 too large
# Past duration 0.828987 too large
# Past duration 0.826653 too large
# Past duration 0.824333 too large
# Past duration 0.827995 too large
# Past duration 0.831657 too large
# Past duration 0.830330 too large
# Past duration 0.828987 too large
# Past duration 0.831657 too large
# Past duration 0.834328 too large
# Past duration 0.836998 too large
# Past duration 0.833321 too large
# Past duration 0.834663 too large
# Past duration 0.835991 too large
# Past duration 0.837318 too large
# Past duration 0.838661 too large
# Past duration 0.839989 too large
# Past duration 0.841331 too large
# Past duration 0.842659 too large
# Past duration 0.840660 too large
# Past duration 0.838661 too large
# Past duration 0.842323 too large
#     Last message repeated 3 times
# Past duration 0.845985 too large
# Past duration 0.846321 too large
# Past duration 0.846657 too large
# Past duration 0.846992 too large
# Past duration 0.847328 too large
# Past duration 0.847664 too large
# Past duration 0.848000 too large
# Past duration 0.851326 too large
# Past duration 0.854652 too large
# Past duration 0.852654 too large
# Past duration 0.853996 too large
# Past duration 0.855324 too large
# Past duration 0.856667 too large
# Past duration 0.857994 too large
# Past duration 0.859322 too large
# Past duration 0.860664 too large
# Past duration 0.861992 too large
# Past duration 0.859993 too large
# Past duration 0.860985 too large
# Past duration 0.861992 too large
# Past duration 0.862999 too large
# Past duration 0.863991 too large
# Past duration 0.864998 too large
# Past duration 0.865990 too large
# Past duration 0.866997 too large
# Past duration 0.867989 too large
# Past duration 0.868996 too large
# Past duration 0.869987 too large
# Past duration 0.870995 too large
# Past duration 0.871986 too large
# Past duration 0.872993 too large
# Past duration 0.873985 too large
# Past duration 0.874992 too large
# Past duration 0.875999 too large
# Past duration 0.876991 too large
# Past duration 0.877998 too large
# Past duration 0.878990 too large
# Past duration 0.879997 too large
# Past duration 0.877663 too large
# Past duration 0.878654 too large
# Past duration 0.879662 too large
# Past duration 0.880653 too large
# Past duration 0.881660 too large
# Past duration 0.882652 too large
# Past duration 0.883659 too large
# Past duration 0.884666 too large
# Past duration 0.885658 too large
# Past duration 0.886665 too large
# Past duration 0.887657 too large
# Past duration 0.888664 too large
# Past duration 0.889656 too large
# Past duration 0.890663 too large
# Past duration 0.891655 too large
# Past duration 0.892662 too large
# Past duration 0.893654 too large
# Past duration 0.894661 too large
# Past duration 0.895653 too large
# Past duration 0.896660 too large
# Past duration 0.897652 too large
# Past duration 0.898659 too large
# Past duration 0.899666 too large
# Past duration 0.900658 too large
# Past duration 0.901665 too large
# Past duration 0.899330 too large
# Past duration 0.896996 too large
# Past duration 0.900658 too large
# Past duration 0.904320 too large
# Past duration 0.902992 too large
# Past duration 0.901665 too large
# Past duration 0.904320 too large
# Past duration 0.906990 too large
# Past duration 0.909660 too large
# Past duration 0.905998 too large
# Past duration 0.907326 too large
# Past duration 0.908653 too large
# Past duration 0.909996 too large
# Past duration 0.911324 too large
# Past duration 0.912666 too large
# Past duration 0.913994 too large
# Past duration 0.915321 too large
# Past duration 0.916664 too large
# Past duration 0.914330 too large
# Past duration 0.915657 too large
# Past duration 0.917000 too large
# Past duration 0.918327 too large
# Past duration 0.919655 too large
# Past duration 0.920998 too large
# Past duration 0.922325 too large
# Past duration 0.923653 too large
# Past duration 0.920998 too large
# Past duration 0.922325 too large
# Past duration 0.923653 too large
# Past duration 0.924995 too large
# Past duration 0.926323 too large
# Past duration 0.927666 too large
# Past duration 0.928993 too large
# Past duration 0.930321 too large
# Past duration 0.928322 too large
# Past duration 0.926323 too large
# Past duration 0.928993 too large
# Past duration 0.931664 too large
# Past duration 0.934319 too large
# Past duration 0.932320 too large
# Past duration 0.930321 too large
# Past duration 0.933662 too large
# Past duration 0.936989 too large
# Past duration 0.935326 too large
# Past duration 0.933662 too large
# Past duration 0.936653 too large
# Past duration 0.939659 too large
# Past duration 0.938988 too large
# Past duration 0.938332 too large
# Past duration 0.937660 too large
# Past duration 0.941658 too large
# Past duration 0.945656 too large
# Past duration 0.941994 too large
# Past duration 0.943321 too large
# Past duration 0.944664 too large
# Past duration 0.945992 too large
# Past duration 0.947319 too large
# Past duration 0.948662 too large
# Past duration 0.949989 too large
# Past duration 0.951332 too large
# Past duration 0.948662 too large
# Past duration 0.949654 too large
# Past duration 0.950661 too large
# Past duration 0.951653 too large
# Past duration 0.952660 too large
# Past duration 0.953651 too large
# Past duration 0.954659 too large
# Past duration 0.955666 too large
# Past duration 0.956657 too large
# Past duration 0.957664 too large
# Past duration 0.958656 too large
# Past duration 0.959663 too large
# Past duration 0.960655 too large
# Past duration 0.961662 too large
# Past duration 0.962654 too large
# Past duration 0.963661 too large
# Past duration 0.964653 too large
# Past duration 0.965660 too large
# Past duration 0.966652 too large
# Past duration 0.967659 too large
# Past duration 0.965324 too large
# Past duration 0.966331 too large
# Past duration 0.967323 too large
# Past duration 0.968330 too large
# Past duration 0.969322 too large
# Past duration 0.970329 too large
# Past duration 0.971321 too large
# Past duration 0.972328 too large
# Past duration 0.973320 too large
# Past duration 0.974327 too large
# Past duration 0.975319 too large
# Past duration 0.976326 too large
# Past duration 0.977333 too large
# Past duration 0.978325 too large
# Past duration 0.979332 too large
# Past duration 0.980324 too large
# Past duration 0.981331 too large
# Past duration 0.982323 too large
# Past duration 0.983330 too large
# Past duration 0.984322 too large
# Past duration 0.985329 too large
# Past duration 0.986320 too large
# Past duration 0.987328 too large
# Past duration 0.984322 too large
# Past duration 0.985664 too large
# Past duration 0.986992 too large
# Past duration 0.988319 too large
# Past duration 0.989662 too large
# Past duration 0.990990 too large
# Past duration 0.992332 too large
# Past duration 0.993660 too large
# Past duration 0.994987 too large
# Past duration 0.992332 too large
# Past duration 0.993660 too large
# Past duration 0.994987 too large
# Past duration 0.996330 too large
# Past duration 0.997658 too large
# Past duration 0.998985 too large
# frame=13300 fps=114 q=-1.0 Lsize=    5866kB time=00:07:23.29 bitrate= 108.4kbits/s dup=0 drop=10 speed= 3.8x
# video:1640kB audio:3762kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 8.601617%
# [libx264 @ 0x5641947fe800] frame I:54    Avg QP:20.20  size:  6601
# [libx264 @ 0x5641947fe800] frame P:5597  Avg QP:24.10  size:   184
# [libx264 @ 0x5641947fe800] frame B:7649  Avg QP:33.04  size:    38
# [libx264 @ 0x5641947fe800] consecutive B-frames: 17.8% 13.0% 10.6% 58.6%
# [libx264 @ 0x5641947fe800] mb I  I16..4:  0.1%  2.7% 97.3%
# [libx264 @ 0x5641947fe800] mb P  I16..4:  0.0%  0.0%  0.1%  P16..4: 18.1%  2.6%  3.3%  0.0%  0.0%    skip:75.9%
# [libx264 @ 0x5641947fe800] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  4.5%  1.1%  0.7%  direct: 1.0%  skip:92.8%  L0:27.4% L1:60.7% BI:12.0%
# [libx264 @ 0x5641947fe800] 8x8 transform intra:4.2% inter:33.4%
# [libx264 @ 0x5641947fe800] coded y,uvDC,uvAC intra: 99.6% 83.4% 57.6% inter: 4.9% 2.6% 0.6%
# [libx264 @ 0x5641947fe800] i16 v,h,dc,p:  0% 100%  0%  0%
# [libx264 @ 0x5641947fe800] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 13% 18%  5%  6%  7%  6%  8%  8%
# [libx264 @ 0x5641947fe800] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 12% 13%  8%  6% 10%  5% 11% 10%
# [libx264 @ 0x5641947fe800] i8c dc,h,v,p: 56% 20% 21%  3%
# [libx264 @ 0x5641947fe800] Weighted P-Frames: Y:0.2% UV:0.0%
# [libx264 @ 0x5641947fe800] ref P L0: 83.7%  6.6%  6.5%  3.1%  0.0%
# [libx264 @ 0x5641947fe800] ref B L0: 89.1%  8.0%  3.0%
# [libx264 @ 0x5641947fe800] ref B L1: 95.4%  4.6%
# [libx264 @ 0x5641947fe800] kb/s:30.29
# [aac @ 0x5641947ff700] Qavg: 211.750

# %%
# !pip install scikit-video --quiet

# %%
from skvideo.io import vread
import skvideo

# %%
data = vread('output_160.mp4')
data.shape
# Out:
# (13300, 90, 160, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def draw_trail(video_data):
  
#   video_data = video_data_in[:,:,:,1]
  
#   print(video_data.shape)
  
  frames, height, width = video_data.shape

  trail_frame = np.zeros([height, width])

  for i in range( len(video_data)-1 ):

    base_frame = video_data[i].astype(np.int32)
    next_frame = video_data[i+1].astype(np.int32)

    delta = abs(base_frame - next_frame)
    
    change_mask = delta > 20
    
    trail_frame[change_mask] += 100

  trail_frame = np.clip(trail_frame, 0, 255).astype(np.uint8)
#   plt.figure(dpi=150)
#   plt.grid(False)
#   plt.imshow(trail_frame)
  return trail_frame

# %%
plt.imshow(draw_trail(data[:,:,:,0]))

# %%
window = 75
deltas = np.zeros([len(data)-window, data.shape[1], data.shape[2]])

for i in range(len(data)-window):
#   print(i, i+30)
  next_frame = draw_trail(data[i:i+window,:,:,0])
#   plt.imshow(next_frame)
  deltas[i] = next_frame

# %%
deltas.shape
# Out:
# (13225, 90, 160)

# %%
skvideo.io.vwrite('deltas_160.mp4', deltas)

# %%
# !gsutil cp deltas_160.mp4 gs://rugby-videos/deltas_160.mp4
# Out:
# Copying file://deltas_160.mp4 [Content-Type=video/mp4]...
# / [1 files][  2.2 MiB/  2.2 MiB]
# Operation completed over 1 objects/2.2 MiB.
